# %% [markdown]
# # End-to-end inference on the test set
#
# Uses fitted parameters (from [`fit-model.ipynb`](fit-model.ipynb)) and the
# **two-track** inference procedure (`infer_all`) to infer $z^{EV}$ and $C$ for
# every test home from **total grid power alone**.
#
# The two EV hypotheses are inferred separately (specs/model.md §4):
#
# - **C = 0 (no EV)** — no sampling. z^EV is pinned off, the model collapses to
#   the Non-EV daily LDS, and one Kalman smoother gives the exact posterior over
#   $z^{LDS}$ and the marginal $\log p(x\mid C{=}0)$.
# - **C = 1 (EV)** — three-block Gibbs over $(\Theta, z^{EV}, z^{LDS})$:
#   1. $z^{EV}\mid\Theta, z^{LDS}$ — HMM forward-filter backward-sample.
#   2. $\Theta_k\mid z^{EV}, z^{LDS}$ — truncated-Normal conjugate per state.
#   3. $z^{LDS}\mid z^{EV}, \Theta$ — Kalman FFBS on residuals $x-\Theta_{z^{EV}}$.
#
# Then $\log p(x, C{=}0)$ and $\log p(x, C{=}1)$ are compared; $\hat C$ is the
# argmax and $\hat P(C{=}1\mid x)$ is the softmax of the two log-evidences (see §9).
#
# Notebook structure:
# 1. Imports + load fitted model + test data
# 2. Heuristic baseline (for C-prediction comparison)
# 3. Run two-track inference over test homes
# 4. C confusion matrix
# 5. $z^{EV}$ confusion matrices (per-home, averaged)
# 6. Convergence diagnostics on one EV home (loglik, $\Theta$ trace, state occupancy)
# 7. Posterior $z^{EV}$ heatmaps — one EV home, one non-EV home
# 8. Did the LDS over-attribute? — $\hat z^{LDS}$ posterior vs ground-truth $x^{NonEV}$
# 9. Model-evidence comparison — $\log p(x, C{=}0)$ vs $\log p(x, C{=}1)$ per home

# %% [markdown]
# ## 1. Imports + data

# %%
import sys, pickle
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

PROJECT_ROOT = Path('../..').resolve()
sys.path.insert(0, str(PROJECT_ROOT))
sys.path.insert(0, str(PROJECT_ROOT / 'notebooks' / 'utils'))

from data_utils import load_split
from models import graphical_model as gm
from models import first_diff_logistic as fdl
import gibbs_diagnostics as gd   # z^EV colour helpers (discrete + fuzzy blend)
import infer_plots as ip   # presentation plots for this notebook

# %%
# ── CONFIGURE ──────────────────────────────────────────────────────────────
FITTED_PARAMS_PATH = PROJECT_ROOT / 'models' / 'fitted_params_full_diagonal.pkl'
# ───────────────────────────────────────────────────────────────────────────

with open(FITTED_PARAMS_PATH, 'rb') as f:
    params: gm.ModelParams = pickle.load(f)
print(params.summary())
# Out:
# ModelParams summary
# ...
# EV States
#   p_C                 = 0.1667
#   pi_z                = [0.8304 0.0419 0.1276]
#   P_z (rows sum to 1):
#       off: [0.9875 0.0085 0.004 ]
#       low: [0.3498 0.515  0.1352]
#      high: [0.0232 0.1294 0.8474]
#
# EV Charging Magnitudes
#   Theta[ off]: mu=+0.0000, sigma_Theta=0.0000, sigma^EV=0.0010
#   Theta[ low]: mu=+0.8727, sigma_Theta=0.1326, sigma^EV=0.4859
#   Theta[high]: mu=+3.5616, sigma_Theta=0.6219, sigma^EV=0.7378
#
# Non-EV — per-home daily LDS
# LDSParams summary
# ----------------------------------------
#   latent_dim L = 96, obs_dim M = 96
#   A             shape=(96, 96)  (identity? False)
#   C             shape=(96, 96)  (identity? False)
#   mu_0          (min=-5.994, median=+0.702, max=+10.459)
#   diag(Sigma_0) (min=0.0485, median=0.2146, max=2996.9971)
#   diag(Q)       (min=0.3703, median=0.7710, max=1.9299)
#   diag(R)       (min=0.1323, median=0.2145, max=0.3158)

# %%
train_df = load_split(str(PROJECT_ROOT / 'data_processing' / 'splits' / 'train.pkl'))
test_df  = load_split(str(PROJECT_ROOT / 'data_processing' / 'splits' / 'test.pkl'))
T = gm.T
print(f'train: {train_df.home_id.nunique():>3} homes')
print(f'test : {test_df.home_id.nunique():>3} homes  '
      f'({test_df.groupby("home_id")["has_ev"].first().sum()} EV, '
      f'{(1-test_df.groupby("home_id")["has_ev"].first()).sum()} non-EV)')
# Out:
# train:  54 homes
# test :  18 homes  (3 EV, 15 non-EV)

# %% [markdown]
# ## 2. Heuristic baseline
#
# The first-diff logistic heuristic is the **C-prediction baseline** for
# comparison; it's not used as a Gibbs warm-start (the collapsed sampler
# cold-starts). Tuned on train, applied to test.

# %%
homes_train = gm.build_heuristic_homes(train_df)
logistic_model, w, lo, hi, md = fdl.tune(homes_train)
print(f'Heuristic tuned: window={w*15}min  low={lo:.2f}  high={hi:.2f}  max_dur={md}')

homes_test = gm.build_heuristic_homes(test_df)
heur_summary, heur_states_test = fdl.predict(
    logistic_model, homes_test, w, lo, hi, md,
)
heur_c_probs = dict(zip(
    heur_summary['dataid'].astype(int),
    heur_summary['p_hat'].astype(float),
))
# Out:
# Best: window=6 (90 min), low=1.2, high=1.6, max_duration=16 (240 min)  (train avg precision=0.5502)
# Heuristic tuned: window=90min  low=1.20  high=1.60  max_dur=16

# %% [markdown]
# ## 3. Run two-track inference over test homes
#
# For each home `infer_all` runs the exact C=0 smoother *and* the C=1 Gibbs
# sampler, then compares the two evidences. Per-iter cost is dominated by the
# Kalman FFBS over $z^{LDS}$ ($O(D \cdot T^3)$ per home per iter), so restrict
# `HOME_IDS` to a manageable subset during development.
#
# `decision='rb'` uses the z^LDS-marginal evidence estimate (A′) for the hard
# $\hat C$ / soft $\hat P(C{=}1)$ — the plug-in joint (A) is not comparable across
# the two hypotheses (it includes the $z^{LDS}$ prior; see §9).

# %%
# ── CONFIGURE ──────────────────────────────────────────────────────────────
S_BURN   = 50
S_RETAIN = 200
SEED     = 0
DECISION = 'chib'    # which C=1 evidence drives Ĉ: 'rb' (z^LDS-marginal A′) or 'plugin' (A)
HOME_IDS = test_df['home_id'].unique()              # all test homes (slow)
# HOME_IDS = sorted(test_df['home_id'].unique())[:6]   # subset for development
# ───────────────────────────────────────────────────────────────────────────

_ids        = set(HOME_IDS)
test_df_sub = test_df[test_df['home_id'].isin(_ids)]
n_ev_sub    = int(test_df_sub.groupby('home_id')['has_ev'].first().sum())
print(f'Running two-track inference on {len(_ids)} homes  '
      f'(of which {n_ev_sub} EV)  '
      f'S_burn={S_BURN}, S_retain={S_RETAIN}, seed={SEED}, decision={DECISION!r}')
# Out:
# Running two-track inference on 18 homes  (of which 3 EV)  S_burn=50, S_retain=200, seed=0, decision='chib'

# %%
inferences = gm.infer_all(
    test_df_sub, params,
    S_burn=S_BURN, S=S_RETAIN, seed=SEED,
    decision=DECISION, verbose=True,
)
# Out:
# ...
# INFERENCE: C=0 (exact) + C=1 (Gibbs) per home, then compare
# ...
#
# [1/18] home 142  D=183  true_c=0
#   [home 142] C=0 (exact): log p(x|C=0)=-8563.4  log p(x,C=0)=-8563.6
#   [home 142] D=183 → C=1 Gibbs (50 burn-in + 200 retained)
#     iter    1/250 [burn-in]  Θ_low=0.505  Θ_high=3.995  logL=-3073.2  (0.1s)
#     iter    2/250 [burn-in]  Θ_low=0.435  Θ_high=2.930  logL=-6051.6  (0.2s)
#     iter    3/250 [burn-in]  Θ_low=0.389  Θ_high=2.529  logL=-6017.9  (0.3s)
#     iter   51/250 [keep  ]  Θ_low=0.392  Θ_high=2.042  logL=-6023.4  (5.3s)
#     iter  100/250 [keep  ]  Θ_low=0.256  Θ_high=2.054  logL=-6069.2  (10.5s)
#     iter  200/250 [keep  ]  Θ_low=0.360  Θ_high=2.224  logL=-5982.5  (21.0s)
#   [home 142] C=1 done in 26.3s
#     z freq : off=0.991  low=0.007  high=0.001
#     Θ[ low] : mean=0.341  std=0.0765
#     Θ[high] : mean=2.285  std=0.2814
#     log p(x,C=1)  plug-in=-17518.2  (A′ z^LDS-marg=-8808.4)
#     Chib: ord(z^EV)=-99.58  ord(Θ)=-8.82  ord(z^LDS)=-8709.82
# ...

# %% [markdown]
# ## 4. C confusion matrix
#
# Absolute **home counts** (not rates), rows = true $C$, columns = predicted
# $\hat C$, accuracy in the title. One figure per predictor.
#
# `C_EVIDENCE` selects which C=1 evidence estimate drives the two-track decision
# without re-running inference: `'rb'` (z^LDS-marginal A′, the default), `'plugin'`
# (A), or `'chib'` (B, if computed).

# %%
# ── CONFIGURE ──────────────────────────────────────────────────────────────
C_EVIDENCE = 'rb'   # which C=1 evidence drives the two-track Ĉ: 'rb' | 'plugin' | 'chib'
# ───────────────────────────────────────────────────────────────────────────

true_c    = ip.true_c_by_home(test_df_sub)
ev_hids     = [hid for hid in inferences if true_c.get(hid, 0) == 1]
non_ev_hids = [hid for hid in inferences if true_c.get(hid, 0) == 0]

pred_tt   = ip.two_track_c_pred(inferences, which=C_EVIDENCE)
pred_heur = {hid: int(heur_c_probs[hid] >= 0.5)
             for hid in inferences if hid in heur_c_probs}

# z confusion matrices (used in §5) — row-normalised recall, computed once here.
results = gm.evaluate(test_df_sub, inferences, heuristic_states=heur_states_test)

ip.plot_c_confusion(true_c, pred_tt,   f'Two-track  ({C_EVIDENCE} evidence)')
plt.show()
ip.plot_c_confusion(true_c, pred_heur, 'Heuristic baseline')
plt.show()
# Out:
# /Users/jackhsieh/Downloads/residential-power-forecasting/models/graphical_model/evaluation.py:189: RuntimeWarning: Mean of empty slice
#   return np.nanmean(np.stack(cm_list, axis=0), axis=0)

# %% [markdown]
# ## 5. $z^{EV}$ confusion matrices
#
# **Row-normalised recall**: each per-home confusion row is normalised to sum to
# 1 (fraction of true-state-$k$ cells predicted as each state), then averaged
# over homes so every home counts equally. Rows = true state, columns =
# predicted.
#
# - EV homes get the full $3\times3$ matrix.
# - non-EV homes only have true `off` cells, so just that single row is shown.
#
# Three predictors: **hard** (MAP $\hat z$), **soft** (posterior marginals), and
# the **heuristic** baseline.

# %%
variants = [('ev_z_hard', 'non_ev_z_hard', 'hard (MAP ẑ)'),
            ('ev_z_soft', 'non_ev_z_soft', 'soft (posterior)'),
            ('ev_z_heur', 'non_ev_z_heur', 'heuristic')]

fig, axes = plt.subplots(2, 3, figsize=(12, 6),
                         gridspec_kw={'height_ratios': [3, 1.3]})
for j, (evk, nevk, name) in enumerate(variants):
    if results[evk] is not None:
        ip.plot_z_confusion(results[evk], [0, 1, 2],
                            f'EV — {name}', ax=axes[0, j])
    if results[nevk] is not None:
        ip.plot_z_confusion(results[nevk][:1], [0],
                            f'non-EV — {name}', ax=axes[1, j])
fig.suptitle('z^EV confusion — row-normalised recall (per-home, then averaged)',
             y=1.01)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 5b. EV charging magnitudes — estimate vs. empirical spread
#
# For each EV home, the estimated per-home charging magnitude $\hat\Theta_k$ with
# a $\pm1.96\,\sigma^{EV}_k$ band (the **fixed** emission std $\sqrt{\sigma^{2,EV}_k}$)
# versus a jittered strip of the **true** `ev_load` values for cells whose *true*
# charge state is $k$. Low (teal) and high (yellow) share the plot; each home is
# a separate x-axis section.

# %%
ip.plot_ev_magnitudes(test_df_sub, inferences, params, ev_hids)
plt.show()

# %% [markdown]
# ## 6. Convergence diagnostics on one EV home
#
# Three traces from the C=1 track (`HomeResult.c1`):
#
# - `loglik_trace` — complete-data log-likelihood per iter
# - `theta_trace`  — $\Theta_{\mathrm{low}}, \Theta_{\mathrm{high}}$ per iter
# - `state_occ_trace` — fraction of cells in each state per iter
#
# Burn-in boundary shown as a vertical line. After it, the chain should be
# stationary (variation, but no drift).

# %%
ev_hids     = [hid for hid in inferences
               if int(test_df_sub[test_df_sub['home_id']==hid]['has_ev'].iloc[0])]
non_ev_hids = [hid for hid in inferences if hid not in ev_hids]
diag_hid    = ev_hids[0] if ev_hids else next(iter(inferences))
inf_diag    = inferences[diag_hid]
true_c_diag = int(test_df_sub[test_df_sub.home_id==diag_hid]['has_ev'].iloc[0])
print(f'Diagnostics for home {diag_hid}  '
      f'(true C = {true_c_diag}, P̂(C=1) = {inf_diag.c_prob:.3f}, Ĉ = {inf_diag.C_hat})')
# Out:
# Diagnostics for home 1222  (true C = 1, P̂(C=1) = 1.000, Ĉ = 1)

# %%
ip.plot_convergence(inf_diag.c1, title=f'home {diag_hid} — C=1 Gibbs traces')
plt.show()

# %% [markdown]
# ## 7. Posterior $z^{EV}$ carpet heatmaps
#
# **Four separate** wide figures for one home — days along the x-axis (calendar
# dates), time-of-day down the y-axis (UTC, 00:00 at top). Shared palette
# (purple=off, teal=low, yellow=high):
#
# 1. **Truth** (discrete) 2. **Posterior MAP** $\hat z$ (discrete)
# 3. **Posterior fuzzy** $\gamma$ (mass-weighted colour blend)
# 4. **Heuristic** baseline (discrete)

# %%
# ── CONFIGURE ──────────────────────────────────────────────────────────────
CARPET_HOME = ev_hids[0] if ev_hids else next(iter(inferences))
CARPET_DAYS = None    # (start, end) day-index range, or None for all days
# ───────────────────────────────────────────────────────────────────────────

figs = ip.plot_z_carpets(test_df_sub, inferences, heur_states_test,
                         CARPET_HOME, day_range=CARPET_DAYS)
for f in figs:
    plt.show()

# %% [markdown]
# ## 7b. Power decomposition over consecutive days
#
# True vs. predicted **Non-EV** (top: posterior mean $\mathbb{E}[C z^{LDS}\mid x]$)
# and **EV** (bottom: $\hat\Theta[\hat z_{MAP}]$ — the MAP state path × estimated
# magnitude) over a run of consecutive days. Dotted-grey lines mark day
# boundaries.

# %%
# ── CONFIGURE ──────────────────────────────────────────────────────────────
DECOMP_HOME = ev_hids[0] if ev_hids else next(iter(inferences))
DECOMP_DAYS = (0, 5)   # consecutive day-index range
# ───────────────────────────────────────────────────────────────────────────

ip.plot_power_decomposition(test_df_sub, inferences, DECOMP_HOME,
                            day_range=DECOMP_DAYS)
plt.show()

# %% [markdown]
# ## 8. Did the LDS over-attribute to Non-EV?
#
# The diagnostic concern from the LDS migration: a per-home, per-day LDS is
# very flexible and may **eat the EV signal** — i.e. attribute charging power
# to $z^{LDS}$ instead of $z^{EV}$. The Gibbs sampler then under-detects
# those charging events.
#
# To check, compare the posterior mean $\hat z^{LDS,(n)}_d$ to the (held-out,
# never-seen-at-inference) ground-truth $x^{NonEV,(n)}_d$ for one EV home.
#
# What to look for:
#
# - **Healthy fit.** $\hat z^{LDS}_d \approx x^{NonEV}_d$ at most cells; the
#   difference $\hat z^{LDS}_d - x^{NonEV}_d$ is roughly zero-mean noise.
# - **Over-attribution.** $\hat z^{LDS}_d > x^{NonEV}_d$ during true *charging*
#   windows — the LDS soaked up EV power into its own latent.
#
# Below: per-day plot for a few days of one EV home, plus the per-cell mean
# $\hat z^{LDS} - x^{NonEV}$ split by true charging vs off cells.

# %%
# ── CONFIGURE ──────────────────────────────────────────────────────────────
N_DAYS_TO_PLOT            = 4
PREFER_DAYS_WITH_CHARGING = True  # bias day selection toward true-charging days
DIAG_HOME_ID              = None  # override here; None → first EV home
# ───────────────────────────────────────────────────────────────────────────

if not ev_hids:
    print('No EV homes in the inferred set — skipping diagnostic.')
else:
    hid     = DIAG_HOME_ID if DIAG_HOME_ID is not None else ev_hids[0]
    z_lds_m = inferences[hid].c1.z_lds_mean    # C=1 posterior-mean Non-EV (EV removed)
    g       = test_df_sub[test_df_sub['home_id']==hid].sort_values(['day','time_index'])
    D       = g['day'].nunique()
    x_nev   = g['non_ev_load'].to_numpy().reshape(D, T)
    z_tr    = g['charge_state'].to_numpy().reshape(D, T)

    rng = np.random.default_rng(0)
    if PREFER_DAYS_WITH_CHARGING:
        days_with_charging = np.where((z_tr > 0).any(axis=1))[0]
        if len(days_with_charging) >= N_DAYS_TO_PLOT:
            chosen = rng.choice(days_with_charging, size=N_DAYS_TO_PLOT, replace=False)
        else:
            chosen = days_with_charging
    else:
        chosen = rng.choice(D, size=N_DAYS_TO_PLOT, replace=False)
    chosen = sorted(chosen.tolist())
    print(f'Showing home {hid}, days {chosen}')

    tt = np.arange(T) * 15 / 60   # hours of day
    fig, axes = plt.subplots(len(chosen), 1, figsize=(11, 2.5 * len(chosen)),
                              sharex=True)
    if len(chosen) == 1: axes = [axes]

    for ax, d in zip(axes, chosen):
        ax.plot(tt, x_nev[d],     lw=1.2, color='C0',
                label=r'true $x^{NonEV}_d$')
        ax.plot(tt, z_lds_m[d],   lw=2.0, color='C1',
                label=r'posterior mean $\hat z^{LDS}_d$')
        chg = z_tr[d] > 0
        if chg.any():
            ax.fill_between(tt, 0, 1, where=chg, transform=ax.get_xaxis_transform(),
                            color='C3', alpha=0.15,
                            label='true charging window')
        ax.set_title(f'home {hid}, day {d}')
        ax.set_ylabel('kW')
        ax.legend(loc='upper right', fontsize=8); ax.grid(alpha=0.3)
    axes[-1].set_xlabel('hour of day')
    plt.tight_layout(); plt.show()

    # Quantitative: split residual by true-state mask
    diff = z_lds_m - x_nev                                       # (D, T)
    chg  = z_tr > 0
    if chg.any():
        print(f'\nMean (ẑ^LDS − x^NonEV) during true charging cells: '
              f'{diff[chg].mean():+.4f} kW')
        print(f'Mean (ẑ^LDS − x^NonEV) during true off cells     : '
              f'{diff[~chg].mean():+.4f} kW')
        print('  Positive value in the charging row ⇒ LDS soaked up EV power.')
# Out:
# Showing home 1222, days [30, 79, 127, 146]
# Mean (ẑ^LDS − x^NonEV) during true charging cells: -0.4822 kW
# Mean (ẑ^LDS − x^NonEV) during true off cells     : -0.2448 kW
#   Positive value in the charging row ⇒ LDS soaked up EV power.

# %% [markdown]
# # 9. Model-evidence comparison
#
# For each home, the two hypotheses are scored by their (log) evidence:
#
# - $\log p(x, C{=}0) = \log(1-p_C) + \log p(x\mid C{=}0)$ — exact (Kalman marginal).
# - $\log p(x, C{=}1)$ — estimated as **A′** (z^LDS integrated out, only $z^{EV*}$
#   plugged in): $\log p_C + \log p(z^{EV*}\mid C{=}1) + \log p(x\mid z^{EV*},
#   C{=}1, \Theta^*)$. This is comparable to the C=0 evidence (both are densities
#   over $x$ alone).
#
# We **do not** plot the plug-in joint (A) against C=0: A is a joint density that
# includes the $\sim\!D\!\times\!L$-dim $z^{LDS}$ latent, so it lives in a
# higher-dimensional space and is not on the same scale.
#
# $\hat C = \mathbb{1}[\log p(x,C{=}1) > \log p(x,C{=}0)]$ and
# $\hat P(C{=}1\mid x)$ is the softmax of the two.

# %%
# Per-home evidence table + Δ = log p(x,C=1)[A′] − log p(x,C=0).
rows = []
for hid, inf in inferences.items():
    true_c = int(test_df_sub[test_df_sub.home_id == hid]['has_ev'].iloc[0])
    rows.append(dict(
        home_id = hid, true_c = true_c,
        logp_C0 = inf.log_evidence_c0,
        logp_C1 = inf.log_evidence_c1,          # A′ (the decision estimate)
        delta   = inf.log_evidence_c1 - inf.log_evidence_c0,
        p_C1    = inf.c_prob,
        C_hat   = inf.C_hat,
    ))
ev_tbl = pd.DataFrame(rows).sort_values(['true_c', 'home_id'],
                                        ascending=[False, True]).reset_index(drop=True)
ev_tbl['correct'] = np.where(ev_tbl.true_c == ev_tbl.C_hat, '✓', '✗')
with pd.option_context('display.float_format', lambda v: f'{v:,.1f}'):
    print(ev_tbl.to_string(index=False))

# Δ per home: positive ⇒ model favours C=1. Colour by ground truth.
fig, ax = plt.subplots(figsize=(11, 4))
colors = ['C1' if c else 'C0' for c in ev_tbl.true_c]
ax.bar(np.arange(len(ev_tbl)), ev_tbl.delta, color=colors)
ax.axhline(0, color='k', lw=0.8)
ax.set_xticks(np.arange(len(ev_tbl)))
ax.set_xticklabels([f'{h}\n({"EV" if c else "non-EV"})'
                    for h, c in zip(ev_tbl.home_id, ev_tbl.true_c)], fontsize=8)
ax.set_ylabel(r'$\log p(x,C{=}1) - \log p(x,C{=}0)$')
ax.set_title('Model-evidence margin per home  '
             '(orange = true EV, blue = true non-EV;  >0 ⇒ predicts EV)')
ax.grid(alpha=0.3, axis='y')
plt.tight_layout(); plt.show()
# Out:
#  home_id  true_c   logp_C0   logp_C1    delta  p_C1  C_hat correct
#     1222       1 -34,417.6 -16,751.4 17,666.2   1.0      1       ✓
#     1642       1 -39,115.3 -29,683.9  9,431.4   1.0      1       ✓
#     5679       1 -29,315.4 -13,265.0 16,050.4   1.0      1       ✓
#      142       0  -8,563.6  -8,709.5   -145.9   0.0      0       ✓
#     1417       0 -12,649.2 -10,878.0  1,771.2   1.0      1       ✗
#     2318       0 -11,208.4 -10,654.9    553.5   1.0      1       ✗
#     3517       0 -10,539.9 -10,582.0    -42.1   0.0      0       ✓
#     4495       0 -15,087.6 -15,446.8   -359.2   0.0      0       ✓
#     5587       0 -14,901.7 -12,727.0  2,174.6   1.0      1       ✗
#     5746       0 -24,855.6 -24,371.0    484.6   1.0      1       ✗
#     7114       0 -20,415.1 -19,790.1    625.0   1.0      1       ✗
#     7800       0 -45,517.4 -34,433.0 11,084.4   1.0      1       ✗
#     8061       0 -20,931.3 -19,571.4  1,359.9   1.0      1       ✗
# ...

# %%
# Square scatter: log p(x, C=1) vs log p(x, C=0). EV green, non-EV orange.
ip.plot_evidence_scatter(test_df_sub, inferences, which=DECISION)
plt.show()
